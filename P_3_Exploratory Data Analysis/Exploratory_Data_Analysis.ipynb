# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment</b>
#
# Hello, my name is Sveta Nosova and I am going to review this project. I am very sorry for this egregious delay 🙏 I hope, it wasn't too much incovenient to you. Fortunately, we don't have any technical troubles anymore, so let's get started.
#
#
# Before we start, I want to pay your attention to the color marking:
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ✔️</b>
#
# Great solutions and ideas that can and should be used in the future are in green comments.
# </div>
#
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ⚠️</b>
#
# Yellow color indicates what should be optimized. This is not necessary, but it will be great if you make changes to this project.
# </div>
#
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ❌</b>
#
# Issues that need to be corrected to get right results are indicated in red comments. Note that the project cannot be accepted until these issues are resolved.
# </div>
#
# <hr>
#
# **Please, use some color other than those listed to highlight answers to my comments.**
# I would also ask you **not to change, move or delete my comments** so that it would be easier for me to navigate during the next review.
#
# In addition, my comments are defined as headings.
# They can mess up the content, however, they are convenient, since you can immediately go to them. I will remove the headings from my comments in the next review.
#
#
#
# <hr>
#
# <font color='dodgerblue'>**A few words about the project:**</font> you did a good job, everything is clear and neat, there are  analysis and intermediate conclusions. I still have some questions that I've written in my comments. I've also left there some recommendations for improving the project.
#
#
# I will wait for the project for a second review :)
#
#
#
# 📌 Here are some hints that may help you with Markdown cells:
# <hr style="border-top: 3px solid purple; "></hr>
#
# You can leave comments using this code inside a Markdown cell:
#
#
#     <div class="alert alert-info">
#     <h2> Student's comment</h2>
#
#     Your text here.
#     </div>
#
#
#
#     <font color='red'> This code is used to change text color. </font>
#
# <font color='red'> It will look like this. </font>
#
# If you don't want your comments to be headings, replace **h2** with **b** or just add `<a class="tocSkip">` after the phrase *Student's comment*.
#
#
# You can find out how to **format text** in a Markdown cell or how to **add links** [here](https://sqlbak.com/blog/jupyter-notebook-markdown-cheatsheet) и [and here](https://medium.com/analytics-vidhya/the-ultimate-markdown-guide-for-jupyter-notebook-d5e5abf728fd).
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 2</b>
#
#
# Thank you for sending the corrected version of the project. You've done a great job, I really appreciate it. I've left a few comments titled as **Reviewer's comment 2**. I've also removed the headings from the old comments. i tried to leave a detailed comment about replacing missing values. I hope it will be helpful. Also, there's an issue that impedes runing the whole code, but I proposed a solution 😉
#
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 3</b>
#
# Thank you very much 😊 There's only one read comment, check it out, please. Everything else is great.
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Reviewer's comment 4</b>
#
#
# Everything is great now!
#
# Your project has passed code review. Congratulations 😊
#
#
# <hr>
# Here are some things to keep in mind:
#
# - Some Nan-s can be ignored if we do not have a decent replacement.
#
#
# - Cutting off the whiskers is not always the best solution when dealing with the biased distribution. One should always check the resulting dataframe, printing minimun and maximum.
#
#
# - It's a good practice to leave a comment under each result, whatever it is: a graph, a table or just some number.
#
#
#
#
# - Use lineplot or boxplot for categorical data.
#
#
#
#
# <hr>
#
# Good luck! 😊
#
#
#
# <hr>
#
#
# Best regards,
#
# Sveta
#
# </div>

# %% [markdown]
# # What sells a car?
#
# You're an analyst at Crankshaft List. Hundreds of free advertisements for vehicles are published on your site every day. You need to study data collected over the last few years and determine which factors influence the price of a vehicle.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>  Reviewer's comment ⚠️</b>
#
#
# There's an introduction, which is good. It is important to write an introductory part, because it gives an idea about the content of the project. However, it would be great if you expanded it a little bit, making it lucider.
# </div>

# %% [markdown]
# ## Initialization

# %% [markdown]
# <u>Librerias that will be used in the project are:</u>

# %%
# Loading all the libraries
import pandas as pd
import seaborn as sns 
import numpy as np
from scipy import stats
from pandas.plotting import scatter_matrix 
import matplotlib.pyplot as plt 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %% [markdown]
# ### Load data
#
# The df is loaded with try-except method for non local users

# %%
# Load the data file into a DataFrame
try:
    df= pd.read_csv(r'C:/Users/wolff/Downloads/vehicles_us.csv')
except:
    df= pd.read_csv('/datasets/vehicles_us.csv')

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment ❌</b>
#
# Are we supposed to use `read_excel` here? Please, make sure that all the cells work fine. To do that, just run them all:
#
#
# ![image.png](attachment:image.png)
#
#
#
# This time I'll add the right code below, since you are waiting for too long for the review. However, do not forget to change code above :) </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
#
# <font color='red'>Fixed, an overlook on my part :)</font>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>  Reviewer's comment 2 ✔️</b>
#
# Now it's fine :) By the way, it's very good that you use `try-except`. Although it is usually used for catching some specific exceptions, it can be used here as well. Another good practice is to add `else` and `finally`. Thus, `try` block allows us to handle some error. The `except` block catches the exceptions. `else` does something if there's no error. `finally` is to be executed in any case, whether there is an exception or not (it is useful when you definitely need to do something, for example, to close a file).
#
#
# Look at this code snippet:
# </div>
#
# ```python
#
# try:
#     # Try to do smth here.
# except Exception as e:
#     # Handle an instance of SomeException.
#     # So we deal with the expected error.
# else:
#     # Do smth if there is no exception.
# finally:
#     # Do something no matter what.
#
# ```

# %%
# Reviewer's code

# Load the data file into a DataFrame
try:
    df= pd.read_csv(r'C:/Users/wolff/Downloads/vehicles_us.csv')
except:
    df= pd.read_csv('/datasets/vehicles_us.csv')

# %% [markdown]
# ### Explore initial data

# %% [markdown]
# The dataset contains the following fields:
# - `price`
# - `model_year`
# - `model`
# - `condition`
# - `cylinders`
# - `fuel` — gas, diesel, etc.
# - `odometer` — the vehicle's mileage when the ad was published
# - `transmission`
# - `paint_color`
# - `is_4wd` — whether the vehicle has 4-wheel drive (Boolean type)
# - `date_posted` — the date the ad was published
# - `days_listed` — from publication to removal

# %%
# print the general/summary information about the DataFrame
df.shape
print('------------------------------------')
df.info()
# Out:
# (51525, 13)
# ------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %%
# print a sample of data
df.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV         NaN     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     NaN  2019-02-07           79
# 3    automatic  pickup         NaN     NaN  2019-03-22            9
# 4    automatic   sedan       black     NaN  2019-04-02           28

# %% [markdown]
# <u>Data description and evaluation:</u>
#
# - 4 columns of missing with seemingly missing data:
#
#     - **model_year** - 3,619 Missing values
#     - **cylinders** - 5,260 Missing values
#     - **odometer** - 7,892 Missing values
#     - **paint_color** - 9,267 Missing values
#     - **is_4wd** - 25,953 Missing values - Max mising values (Boolean type)
#
#
#
# - Data type issue:
#
#     - **date_posted** - is object need to format to date
#     - **model_year** - shouldnt be a float64 but an int64
#     - **cylinders** - shouldnt be a float64 but an int64

# %% [markdown]
# ### Conclusions and further steps
#
# 1. Columns 'model_year', 'cylinders', 'paint_color' where we have missing data is probebly due to incorect data input. there is    no logical resone for missing data otherwise.
#
# 2. Columns 'is_4wd' and 'odometer' where we have missing data might be due to the fact that not all cars have 4-wheel drive and
#    some cars might hade 0 mileage when the ad was published and the data wasent filled resulting in missing value.
#
#    * For 'is_4wd' i will replace all missing values with 0, 'is_4wd' is a boolean type 1 there is 4-wheel drive and 0 if not
#      my assumption is all missing values are non 4-wheel drive.
#
#    * For 'odometer' in will fill the missing value with 0 since my assumption is that it was simply left blank due to it beeing      mileage when the ad was published.
#
#    * For model_year i will use median to fillna
#
#    * For paint_color i will replace na with string "unknown" and will not use it
#
#    * For cylinders will fillna by model with transformer method

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b>   Reviewer's comment ✔️</b>
#
# Nice introductory part.
#
#
# I'll leave more detailed comments about Nan-s replacement. </div>

# %% [markdown]
# ## Treat missing values (if any)

# %%
df.isna().sum().sort_values(ascending=False).to_frame('missing_values')
# Out:
#               missing_values
# is_4wd                 25953
# paint_color             9267
# odometer                7892
# cylinders               5260
# model_year              3619
# price                      0
# model                      0
# condition                  0
# fuel                       0
# transmission               0
# type                       0
# date_posted                0
# days_listed                0

# %%
mis_values = df.isnull().sum().to_frame('missing_values')
mis_values['%'] = (round(df.isnull().sum()/len(df),3))*100
mis_values.sort_values(by='%', ascending=False)
# Out:
#               missing_values     %
# is_4wd                 25953  50.4
# paint_color             9267  18.0
# odometer                7892  15.3
# cylinders               5260  10.2
# model_year              3619   7.0
# price                      0   0.0
# model                      0   0.0
# condition                  0   0.0
# fuel                       0   0.0
# transmission               0   0.0
# type                       0   0.0
# date_posted                0   0.0
# days_listed                0   0.0

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ✔️</b>
#
# Yes, it is much better to see the percentage of missing values. You can use `df.isna().mean()*100`  or something like this:
#
#
# </div>

# %%
# Reviewer's code

pd.DataFrame(df.isna().mean()*100).sort_values(by=0)[::-1].style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_6328d_row0_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_6328d_row1_col0{
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }#T_6328d_row2_col0{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_6328d_row3_col0{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_6328d_row4_col0{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_6328d_row5_col0,#T_6328d_row6_col0,#T_6328d_row7_col0,#T_6328d_row8_col0,#T_6328d_row9_col0,#T_6328d_row10_col0,#T_6328d_row11_col0,#T_6328d_row12_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_6328d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
df['is_4wd'] = df['is_4wd'].fillna(0)

# %%
mis_values = df.isnull().sum().to_frame('missing_values')
mis_values['%'] = (round(df.isnull().sum()/len(df),3))*100
mis_values.sort_values(by='%', ascending=False)
# Out:
#               missing_values     %
# paint_color             9267  18.0
# odometer                7892  15.3
# cylinders               5260  10.2
# model_year              3619   7.0
# price                      0   0.0
# model                      0   0.0
# condition                  0   0.0
# fuel                       0   0.0
# transmission               0   0.0
# type                       0   0.0
# is_4wd                     0   0.0
# date_posted                0   0.0
# days_listed                0   0.0

# %% [markdown]
# First column that i filled is 'is_4wd' as per my assumption that all missind values should be 0 as they dont have a 4-wheel drive
# ***

# %%
year = df.model_year.sort_values(ascending=False)
print(year.unique())
# Out:
# [2019. 2018. 2017. 2016. 2015. 2014. 2013. 2012. 2011. 2010. 2009. 2008.
#  2007. 2006. 2005. 2004. 2003. 2002. 2001. 2000. 1999. 1998. 1997. 1996.
#  1995. 1994. 1993. 1992. 1991. 1990. 1989. 1988. 1987. 1986. 1985. 1984.
#  1983. 1982. 1981. 1980. 1979. 1978. 1977. 1976. 1975. 1974. 1973. 1972.
#  1971. 1970. 1969. 1968. 1967. 1966. 1965. 1964. 1963. 1962. 1961. 1960.
#  1958. 1955. 1954. 1949. 1948. 1936. 1929. 1908.   nan]

# %%
df[df.model_year.isna()]
# Out:
#        price  model_year                       model  condition  cylinders  \
# 1      25500         NaN                  ford f-150       good        6.0
# 20      6990         NaN             chevrolet tahoe  excellent        8.0
# 65     12800         NaN                  ford f-150  excellent        6.0
# 69      7800         NaN                  ford f-150   like new        8.0
# 72      3650         NaN              subaru impreza  excellent        NaN
# ...      ...         ...                         ...        ...        ...
# 51464   8890         NaN        ford f250 super duty       good        8.0
# 51465  34595         NaN                   gmc yukon  excellent        8.0
# 51487   1495         NaN                  ford f-150       fair        6.0
# 51488  21900         NaN  chevrolet silverado 3500hd  excellent        8.0
# 51508   4950         NaN     chrysler town & country  excellent        6.0
#
# ...

# %%
print(df.model_year.describe())
print('-----------------------------------------')
print(df.model_year.mode())
# Out:
# count    47906.000000
# mean      2009.750470
# std          6.282065
# min       1908.000000
# 25%       2006.000000
# 50%       2011.000000
# 75%       2014.000000
# max       2019.000000
# Name: model_year, dtype: float64
# -----------------------------------------
# 0    2013.0
# dtype: float64

# %%
# Reviwer's code

olddf = df.copy()

# %%
df['model_year'] = df['model_year'].fillna(df.groupby('model')['model_year'].transform('median'))

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
#
# Not sure about it. Take a look at **ford f-150**. Min year is 1929 and max is 2019 :)</div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
#
# <font color='red'>As i see it i can fill it with either median or mode, as Avg with be worng (outliers such as 1929) i choose median, is there a diffrent approch ? </font>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 ✔️</b>
#
#
#
# True, the median works better with the outliers, however, we do not know how many strange values like 1929 we have. Moreover, even between two normal year values the gap can be large. So, answering this question and the one that is left below, I can say that ignoring missing values should hurt no  more than replacing them with the median would do.
#
#
# What else can we do here? We can add a condition parameter. On the other hand, we can figure out another solution. We can take only those models, where age gap is not large.
#
# Let's try. First, I created a copy of the dataframe before the replacement. Second, I'll write a function that returns a difference between max and min. Remember, you can use your own functions in **agg** method. Then I'll print the models with the gap less than 15 years. After all, I'll check how many rows that have Nan in `model year` have  a `model` that is also in the list of models with gap under 15. Sounds confusing, but you will understand when you see the code :)
#
# Note: if there was nothing about `query` in the lessons, let me know. I'll rewrite it. </div>

# %%
# Reviewer's code

def minmax(x):
    return max(x) - min(x)

olddf.groupby('model')['model_year'].agg(['min', 'max', minmax])
# Out:
#                       min     max  minmax
# model
# acura tl           1999.0  2014.0    15.0
# bmw x5             2001.0  2018.0    17.0
# buick enclave      2008.0  2018.0    10.0
# cadillac escalade  1908.0  2019.0   111.0
# chevrolet camaro   1967.0  2019.0    52.0
# ...                   ...     ...     ...
# toyota sienna      1998.0  2019.0    21.0
# toyota tacoma      1989.0  2019.0    30.0
# toyota tundra      2000.0  2018.0    18.0
# volkswagen jetta   1996.0  2019.0    23.0
# volkswagen passat  1995.0  2018.0    23.0
#
# [100 rows x 3 columns]

# %%
# Reviewer's code

olddf.groupby('model')['model_year'].agg(['min', 'max', minmax]).query('minmax < 15')
# Out:
#                                       min     max  minmax
# model
# buick enclave                      2008.0  2018.0    10.0
# chevrolet camaro lt coupe 2d       2010.0  2019.0     9.0
# chevrolet cruze                    2006.0  2019.0    13.0
# chevrolet equinox                  2005.0  2019.0    14.0
# chevrolet silverado 1500 crew      2007.0  2018.0    11.0
# chevrolet trailblazer              1999.0  2009.0    10.0
# chevrolet traverse                 2006.0  2019.0    13.0
# chrysler 200                       2009.0  2017.0     8.0
# ford edge                          2007.0  2019.0    12.0
# ford fusion                        2006.0  2019.0    13.0
# ford fusion se                     2005.0  2018.0    13.0
# gmc acadia                         2007.0  2019.0    12.0
# jeep liberty                       2002.0  2012.0    10.0
# kia soul                           2010.0  2018.0     8.0
# mercedes-benz benze sprinter 2500  2013.0  2013.0     0.0
# ...

# %%
# Reviewer's code

ll = list(olddf.groupby('model')['model_year'].agg(['min', 'max', minmax]).query('minmax < 15').index)
ll
# Out:
# ['buick enclave',
#  'chevrolet camaro lt coupe 2d',
#  'chevrolet cruze',
#  'chevrolet equinox',
#  'chevrolet silverado 1500 crew',
#  'chevrolet trailblazer',
#  'chevrolet traverse',
#  'chrysler 200',
#  'ford edge',
#  'ford fusion',
#  'ford fusion se',
#  'gmc acadia',
#  'jeep liberty',
#  'kia soul',
#  'mercedes-benz benze sprinter 2500',
#  'nissan frontier crew cab sv',
#  'nissan rogue',
#  'nissan versa']

# %%
# Reviewer's code

olddf.query('model_year.isna() and model in @ll')
# Out:
#        price  model_year                         model  condition  cylinders  \
# 114    23700         NaN   nissan frontier crew cab sv       good        6.0
# 116    25300         NaN  chevrolet camaro lt coupe 2d       good        6.0
# 159    23300         NaN   nissan frontier crew cab sv       good        NaN
# 199     8499         NaN                  nissan rogue  excellent        4.0
# 309     2500         NaN                  nissan rogue  excellent        4.0
# ...      ...         ...                           ...        ...        ...
# 50911   9995         NaN                  jeep liberty  excellent        6.0
# 50985   5500         NaN                  jeep liberty       good        6.0
# 51156   9495         NaN                  jeep liberty       good        6.0
# 51160  14990         NaN             chevrolet equinox  excellent        4.0
# 51385   3495         NaN                  jeep liberty       good        6.0
#
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 ✔️</b>
#
#
#
# These are cars with a small model age gap. Not too much, but still. We can choose 20 as a threshold instead of 15 and get 800 rows. What is important here, is that we do not consider models that have 50 years age gap (e.g. chevrolet camaro).
#
#
# The next question is how to make the replacement for these models? It's quite simple. I'll demonstrate it with the **olddf** dataframe: </div>

# %%
# Reviewer's code

print('Nan-s Before: ', olddf.model_year.isna().sum())

for model in ll:
    # find a median for each of these models
    median_value = olddf[olddf['model'] == model]['model_year'].median()
    
    # find the rows with these models and use a simple fillna
    olddf.loc[olddf['model']==model, 'model_year'] = olddf.loc[olddf['model']==model, 'model_year'].fillna(median_value)
    
    
print('Nan-s After: ', olddf.model_year.isna().sum())
# Out:
# Nan-s Before:  3619
# Nan-s After:  3176

# %%
print(median_value)
print('----------------')
df.model_year.median()
# Out:
# 2012.0
# ----------------
# 2011.0

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2✔️</b>
#
#
# Of course, it's not much, but it is definitely a safer approach.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 ❌</b>
#
# Do you agree or disagree with it? It would be great if you tried to do the same for the main dataframe 😊
#
# If you do not agree with it, I'll be ok about it, but I would like to know your opinion.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
#
# <font color='red'>I understand the approach its something i will definitely think about next project :)
# In my opinion the median covers more Nan-s and if i look at the median my original df(With the Nan-s) its 2011. In you approch the the median is also 2012 and its very close and i think it dosent make alot of difference </font>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3✔️</b>
#
#
# Got it :) Just wanted to pay you attention on it.
#
# </div>

# %%
# Reviewer's code

df.query('model=="ford f-150"').model_year.describe().loc[['min', 'max']]
# Out:
# min    1929.0
# max    2019.0
# Name: model_year, dtype: float64

# %%
# Reviewer's code

df.query('model=="hyundai sonata"').model_year.describe().loc[['min', 'max']]
# Out:
# min    1997.0
# max    2018.0
# Name: model_year, dtype: float64

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Yes, we take median here. But the point is, there's no strong connection between these parameters, so I would just ignore Nan-s. What do you think?
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
#
# <font color='red'>I choose to fill this with median as i use it for fillna with groupby for cylinders column if i leave it blank will not hurt my further analysis? </font>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2✔️</b>
#
#
# Answered above.
#
# </div>

# %%
df['model_year'].isna().sum()
# Out:
# 0

# %%
mis_values = df.isnull().sum().to_frame('missing_values')
mis_values['%'] = (round(df.isnull().sum()/len(df),3))*100
mis_values.sort_values(by='%', ascending=False)
# Out:
#               missing_values     %
# paint_color             9267  18.0
# odometer                7892  15.3
# cylinders               5260  10.2
# price                      0   0.0
# model_year                 0   0.0
# model                      0   0.0
# condition                  0   0.0
# fuel                       0   0.0
# transmission               0   0.0
# type                       0   0.0
# is_4wd                     0   0.0
# date_posted                0   0.0
# days_listed                0   0.0

# %% [markdown]
# 'model_year' missing values are filed with meadin values by model column
# ***

# %%
df.odometer.isnull().sum()
df.odometer.isnull().groupby([df['condition']]).sum()
# Out:
# 7892
# condition
# excellent    3800
# fair          237
# good         3092
# like new      728
# new            18
# salvage        17
# Name: odometer, dtype: int64

# %%
# Reviewer's code

df[df['odometer']==0.0]['condition'].value_counts()
# Out:
# good         104
# excellent     69
# fair           6
# like new       4
# salvage        2
# Name: condition, dtype: int64

# %%
df['odometer'] = df['odometer'].fillna(df.groupby('model')['model_year'].transform('median'))
df.odometer.isnull().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
#
# There are 185 cars with such odometer values. They can be new cars. Is it save to replace about 8 thousand nan-s with zero here?
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
#
# <font color='red'>The nan-s dont come from any spcifice condition(new for example) thats why i will fill it with median as well  </font>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2✔️</b>
#
#
# Accepted. We should always check out hypotheses if it is possible. Apart from this, among those 185 cars there are no new cars and most of them are in *good* coondition :) That's another important issue that can be investigated (see my code above yours).
# </div>

# %%
df['model_year'].isna().sum()
# Out:
# 0

# %%
mis_values = df.isnull().sum().to_frame('missing_values')
mis_values['%'] = (round(df.isnull().sum()/len(df),3))*100
mis_values.sort_values(by='%', ascending=False)
# Out:
#               missing_values     %
# paint_color             9267  18.0
# cylinders               5260  10.2
# price                      0   0.0
# model_year                 0   0.0
# model                      0   0.0
# condition                  0   0.0
# fuel                       0   0.0
# odometer                   0   0.0
# transmission               0   0.0
# type                       0   0.0
# is_4wd                     0   0.0
# date_posted                0   0.0
# days_listed                0   0.0

# %% [markdown]
# 'odometer' missing values are filled with 0, the reason is a car can be new with 0 mileage when the ad was published or in an     unused condition
# ***

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
#
# It is a very good assumption. However, we should check it before making any conclusions. Let's check the condition distribution for the cars that do not have any adometer values.
#
#
# Note: not the cars with zero, since the dataframe already has some zero-odometer cars, but those rows that have Nan in the odometer column. </div>

# %%
df[df.cylinders.isna()]
# Out:
#        price  model_year              model  condition  cylinders fuel  \
# 9       9200      2008.0        honda pilot  excellent        NaN  gas
# 36     10499      2013.0       chrysler 300       good        NaN  gas
# 37      7500      2005.0      toyota tacoma       good        NaN  gas
# 59      5200      2006.0  toyota highlander       good        NaN  gas
# 63     30000      1966.0       ford mustang  excellent        NaN  gas
# ...      ...         ...                ...        ...        ...  ...
# 51429   3250      2004.0       toyota camry       good        NaN  gas
# 51442  28990      2018.0          ford f150  excellent        NaN  gas
# 51460   5995      2007.0        ford fusion  excellent        NaN  gas
# 51477   6499      2007.0           acura tl       good        NaN  gas
# 51486   5895      2009.0   hyundai santa fe  excellent        NaN  gas
#
#        odometer transmission         type paint_color  is_4wd date_posted  \
# ...

# %%
df['cylinders'] = df['cylinders'].fillna(df.groupby(['model', 'model_year','transmission'])['cylinders'].transform('median'))

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
#
# Although most cars of the same model usually have the same number of cylinders, it's better to add model year in a groupby method. As I've shown above, the age gap can be large, so we can have different number of cylinders.
#
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ⚠️</b>
#
#
# We still cannot assert that the number of cylinders should have a significant correlation with model and its year. Take a look at the example:
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
#
# <font color='red'>
#
# * Added model year to the groupby
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2✔️</b>
#
#
# Cool :)
#
# </div>

# %%
# Reviewer's code

df.groupby(['model', 'model_year'])['cylinders'].nunique().value_counts()
# Out:
# 1    1248
# 2     795
# 3     140
# 0      24
# 4      20
# 5       1
# Name: cylinders, dtype: int64

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ⚠️</b>
#
#
# From the code above we can see that for 1246 cars of a specific model and model year we have exactly one cylinder. However, 836 have two of them and some others have more than 2 cylinders.
#
# If we want to fill in some gaps, we can cosider these 1246 models and use a take a median in a grouping by model and model's year.
#
#
# Another way is to ignore these Nan-s. It is completely ok to ignore missing values if they do not hurt the analysis. </div>

# %%
df['cylinders'].isna().sum()
# Out:
# 86

# %%
df['cylinders'] = df['cylinders'].fillna(1000)

# %%
df['cylinders'].isna().sum()
# Out:
# 0

# %%
mis_values = df.isnull().sum().to_frame('missing_values')
mis_values['%'] = (round(df.isnull().sum()/len(df),3))*100
mis_values.sort_values(by='%', ascending=False)
# Out:
#               missing_values     %
# paint_color             9267  18.0
# price                      0   0.0
# model_year                 0   0.0
# model                      0   0.0
# condition                  0   0.0
# cylinders                  0   0.0
# fuel                       0   0.0
# odometer                   0   0.0
# transmission               0   0.0
# type                       0   0.0
# is_4wd                     0   0.0
# date_posted                0   0.0
# days_listed                0   0.0

# %%
df['paint_color'] = df['paint_color'].fillna('unkown')

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ✔️</b>
#
#
# Agree. It's hard to figure out a safer solution. </div>

# %% [markdown]
# 'cylinders' missing values is replaced with median values grouped by  - 'model_year'
#
# 'paint_color' is filled with - 'unkown'
#
# ***

# %%
mis_values = df.isnull().sum().to_frame('missing_values')
mis_values['%'] = (round(df.isnull().sum()/len(df),3))*100
mis_values.sort_values(by='%', ascending=False)
# Out:
#               missing_values    %
# price                      0  0.0
# model_year                 0  0.0
# model                      0  0.0
# condition                  0  0.0
# cylinders                  0  0.0
# fuel                       0  0.0
# odometer                   0  0.0
# transmission               0  0.0
# type                       0  0.0
# paint_color                0  0.0
# is_4wd                     0  0.0
# date_posted                0  0.0
# days_listed                0  0.0

# %%
df.model.unique()
df['model'] = df['model'].str.replace('-', '')
df['model'] = df['model'].str.replace('mercedesbenz', 'mercedes-benz')
df.model.unique()
# Out:
# array(['bmw x5', 'ford f-150', 'hyundai sonata', 'chrysler 200',
#        'chrysler 300', 'toyota camry', 'honda pilot', 'kia sorento',
#        'chevrolet silverado 1500', 'honda accord', 'ram 1500',
#        'gmc yukon', 'jeep cherokee', 'chevrolet traverse',
#        'hyundai elantra', 'chevrolet tahoe', 'toyota rav4',
#        'chevrolet silverado', 'jeep wrangler', 'chevrolet malibu',
#        'ford fusion se', 'chevrolet impala', 'chevrolet corvette',
#        'jeep liberty', 'toyota camry le', 'nissan altima',
#        'subaru outback', 'toyota highlander', 'dodge charger',
#        'toyota tacoma', 'chevrolet equinox', 'nissan rogue',
#        'mercedes-benz benze sprinter 2500', 'honda cr-v',
#        'jeep grand cherokee', 'toyota 4runner', 'ford focus',
#        'honda civic', 'kia soul', 'chevrolet colorado',
#        'ford f150 supercrew cab xlt', 'chevrolet camaro lt coupe 2d',
#        'chevrolet cruze', 'ford mustang', 'chevrolet silverado 3500hd',
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ✔️</b>
#
#
# Yes, it's very important to check for duplicates.
#
# </div>

# %% [markdown]
# ## Fix data types

# %%
df['model_year'] = df['model_year'].astype('int64')
df['cylinders'] = df['cylinders'].astype('int64')
df['odometer'] = df['odometer'].astype('int64')
df['date_posted'] = pd.to_datetime(df['date_posted'],format='%Y-%m-%d')

# %%
df.cylinders.replace(1000, np.NaN)
# Out:
# 0        6.0
# 1        6.0
# 2        4.0
# 3        8.0
# 4        4.0
#         ...
# 51520    6.0
# 51521    4.0
# 51522    4.0
# 51523    4.0
# 51524    4.0
# Name: cylinders, Length: 51525, dtype: float64

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 2 ❌</b>
#
# Be careful: some Nan-s were not replaced in the **cylinder** column.
#
#
# You can either leave them to be float, or replace these Nan-s with some abnoraml value, like 100, and then convert the column to integer. Don't worry, it is ok to use abnormal values that can be easily detected. It's absolutely the same as *other* color used above. In any case, you can replace Nan with 100, then convert data type and then replace 100 with Nan :)
#
#
#
# I'll review further steps in the next time, since now it's impossible to run the code.  </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
#
# <font color='red'>
#
# * Done :)
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ✔️</b>
#
#
# You can use a `parse_dates` agrument while reading the dataframe. Pandas will try to read the data field. This is a good [article](https://towardsdatascience.com/4-tricks-you-should-know-to-parse-date-columns-with-pandas-read-csv-27355bb2ad0e) with the examples.
# </div>

# %%
df.dtypes.to_frame('datatype')
# Out:
#                     datatype
# price                  int64
# model_year             int64
# model                 object
# condition             object
# cylinders              int64
# fuel                  object
# odometer               int64
# transmission          object
# type                  object
# paint_color           object
# is_4wd               float64
# date_posted   datetime64[ns]
# days_listed            int64

# %%
df.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400        2011          bmw x5       good          6  gas    145000
# 1  25500        2011       ford f150       good          6  gas     88705
# 2   5500        2013  hyundai sonata   like new          4  gas    110000
# 3   1500        2003       ford f150       fair          8  gas      2011
# 4  14900        2017    chrysler 200  excellent          4  gas     80903
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV      unkown     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     0.0  2019-02-07           79
# 3    automatic  pickup      unkown     0.0  2019-03-22            9
# 4    automatic   sedan       black     0.0  2019-04-02           28

# %% [markdown]
# ## Enrich data

# %%
# Add datetime values for when the ad was placed
df['day_of_week'] = pd.DatetimeIndex(df['date_posted']).weekday
df['day'] = pd.DatetimeIndex(df['date_posted']).day
df['month'] = pd.DatetimeIndex(df['date_posted']).month
df['year'] = pd.DatetimeIndex(df['date_posted']).year

# %%
df.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400        2011          bmw x5       good          6  gas    145000
# 1  25500        2011       ford f150       good          6  gas     88705
# 2   5500        2013  hyundai sonata   like new          4  gas    110000
# 3   1500        2003       ford f150       fair          8  gas      2011
# 4  14900        2017    chrysler 200  excellent          4  gas     80903
#
#   transmission    type paint_color  is_4wd date_posted  days_listed  \
# 0    automatic     SUV      unkown     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     0.0  2019-02-07           79
# 3    automatic  pickup      unkown     0.0  2019-03-22            9
# 4    automatic   sedan       black     0.0  2019-04-02           28
#
#    day_of_week  day  month  year
# 0            5   23      6  2018
# 1            4   19     10  2018
# ...

# %%
# Add the vehicle's age when the ad was placed
df['vehicle_age'] = df['year'] - df['model_year']

# %%
df.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400        2011          bmw x5       good          6  gas    145000
# 1  25500        2011       ford f150       good          6  gas     88705
# 2   5500        2013  hyundai sonata   like new          4  gas    110000
# 3   1500        2003       ford f150       fair          8  gas      2011
# 4  14900        2017    chrysler 200  excellent          4  gas     80903
#
#   transmission    type paint_color  is_4wd date_posted  days_listed  \
# 0    automatic     SUV      unkown     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     0.0  2019-02-07           79
# 3    automatic  pickup      unkown     0.0  2019-03-22            9
# 4    automatic   sedan       black     0.0  2019-04-02           28
#
#    day_of_week  day  month  year  vehicle_age
# 0            5   23      6  2018            7
# ...

# %%
# Add the vehicle's average mileage per year
df.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400        2011          bmw x5       good          6  gas    145000
# 1  25500        2011       ford f150       good          6  gas     88705
# 2   5500        2013  hyundai sonata   like new          4  gas    110000
# 3   1500        2003       ford f150       fair          8  gas      2011
# 4  14900        2017    chrysler 200  excellent          4  gas     80903
#
#   transmission    type paint_color  is_4wd date_posted  days_listed  \
# 0    automatic     SUV      unkown     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     0.0  2019-02-07           79
# 3    automatic  pickup      unkown     0.0  2019-03-22            9
# 4    automatic   sedan       black     0.0  2019-04-02           28
#
#    day_of_week  day  month  year  vehicle_age
# 0            5   23      6  2018            7
# ...

# %%
df['vehicle_Avg_mileage'] = (df['odometer'].where(df['vehicle_age'] == 0 , round(df['odometer'] / df['vehicle_age'])))

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ✔️</b>
#
#
# Very good 👍</div>

# %%
mis_values = df.isnull().sum().to_frame('missing_values')
mis_values['%'] = (round(df.isnull().sum()/len(df),3))*100
mis_values.sort_values(by='%', ascending=False)
# Out:
#                      missing_values    %
# price                             0  0.0
# is_4wd                            0  0.0
# vehicle_age                       0  0.0
# year                              0  0.0
# month                             0  0.0
# day                               0  0.0
# day_of_week                       0  0.0
# days_listed                       0  0.0
# date_posted                       0  0.0
# paint_color                       0  0.0
# model_year                        0  0.0
# type                              0  0.0
# transmission                      0  0.0
# odometer                          0  0.0
# fuel                              0  0.0
# cylinders                         0  0.0
# condition                         0  0.0
# model                             0  0.0
# vehicle_Avg_mileage               0  0.0

# %%
# It might help to replace the condition values with something that can be manipulated more easily
df.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400        2011          bmw x5       good          6  gas    145000
# 1  25500        2011       ford f150       good          6  gas     88705
# 2   5500        2013  hyundai sonata   like new          4  gas    110000
# 3   1500        2003       ford f150       fair          8  gas      2011
# 4  14900        2017    chrysler 200  excellent          4  gas     80903
#
#   transmission    type paint_color  is_4wd date_posted  days_listed  \
# 0    automatic     SUV      unkown     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     0.0  2019-02-07           79
# 3    automatic  pickup      unkown     0.0  2019-03-22            9
# 4    automatic   sedan       black     0.0  2019-04-02           28
#
#    day_of_week  day  month  year  vehicle_age  vehicle_Avg_mileage
# ...

# %%
df.condition.unique()
# Out:
# array(['good', 'like new', 'fair', 'excellent', 'salvage', 'new'],
#       dtype=object)

# %%
condition_dict = {'new':5,
                  'like new':4,
                  'excellent':3,
                  'good':2,
                  'fair':1,
                  'salvage':0}

condition_dict.keys()
condition_dict.values()
# Out:
# dict_keys(['new', 'like new', 'excellent', 'good', 'fair', 'salvage'])
# dict_values([5, 4, 3, 2, 1, 0])

# %%
def replace_condition(x):
    return condition_dict[x]

# %%
replace_condition('new')
# Out:
# 5

# %%
check = df['condition'].loc[100]
check
# Out:
# 'good'

# %%
replace_condition(check)
# Out:
# 2

# %%
df['condition_id'] = df['condition'].apply(replace_condition)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ✔️</b>
#
#
# You can also use a simple replace. </div>

# %%
df.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400        2011          bmw x5       good          6  gas    145000
# 1  25500        2011       ford f150       good          6  gas     88705
# 2   5500        2013  hyundai sonata   like new          4  gas    110000
# 3   1500        2003       ford f150       fair          8  gas      2011
# 4  14900        2017    chrysler 200  excellent          4  gas     80903
#
#   transmission    type paint_color  is_4wd date_posted  days_listed  \
# 0    automatic     SUV      unkown     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     0.0  2019-02-07           79
# 3    automatic  pickup      unkown     0.0  2019-03-22            9
# 4    automatic   sedan       black     0.0  2019-04-02           28
#
#    day_of_week  day  month  year  vehicle_age  vehicle_Avg_mileage  \
# ...

# %% [markdown]
# ## Check clean data

# %%
# print the general/summary information about the DataFrame
df.shape
print('------------------------------------')
df.info()
# Out:
# (51525, 20)
# ------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   price                51525 non-null  int64
#  1   model_year           51525 non-null  int64
#  2   model                51525 non-null  object
#  3   condition            51525 non-null  object
#  4   cylinders            51525 non-null  int64
#  5   fuel                 51525 non-null  object
#  6   odometer             51525 non-null  int64
#  7   transmission         51525 non-null  object
#  8   type                 51525 non-null  object
#  9   paint_color          51525 non-null  object
#  10  is_4wd               51525 non-null  float64
#  11  date_posted          51525 non-null  datetime64[ns]
#  12  days_listed          51525 non-null  int64
#  13  day_of_week          51525 non-null  int64
# ...

# %%
# print a sample of data
df.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400        2011          bmw x5       good          6  gas    145000
# 1  25500        2011       ford f150       good          6  gas     88705
# 2   5500        2013  hyundai sonata   like new          4  gas    110000
# 3   1500        2003       ford f150       fair          8  gas      2011
# 4  14900        2017    chrysler 200  excellent          4  gas     80903
#
#   transmission    type paint_color  is_4wd date_posted  days_listed  \
# 0    automatic     SUV      unkown     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     0.0  2019-02-07           79
# 3    automatic  pickup      unkown     0.0  2019-03-22            9
# 4    automatic   sedan       black     0.0  2019-04-02           28
#
#    day_of_week  day  month  year  vehicle_age  vehicle_Avg_mileage  \
# ...

# %% [markdown]
# ## Study core parameters
#
# The parameters are
# - Price
# - The vehicle's age when the ad was placed
# - Mileage
# - Number of cylinders
# - Condition

# %%
def distribution_percentile(parameter):
    print('The histogram of: {}'.format(parameter))
    df[parameter].hist(bins=30)
    plt.title('Distributiot of: {}'.format(parameter))
    plt.xlabel(parameter)
    plt.ylabel('Frequncy')
    plt.show()
    if df[parameter].mean()>df[parameter].median():
        print('The distribution is skewed to the right')
    else:
        print('The distribution is skewed to the left')
    print('---------------------------------------')
    print('Statistics on: {}'.format(parameter))
    print(df[parameter].describe())
    #data[parameter].describe()
    ninety_five = np.percentile(df[parameter], 95)
    five = np.percentile(df[parameter], 5)
    frequency = df[parameter].mode()
    print('---------------------------------------')
    print('min border:',five)
    print('max border:',ninety_five)
    print('Most frequent value:',frequency)
    print('---------------------------------------')
    print('The outliers are considered to be values below',five, "and above",ninety_five)
    print('We have',len(df[(df[parameter]<five)|(df[parameter]>ninety_five)]),"values that we can consider outliers")

# %%
parameters = ['price','vehicle_age','cylinders','condition_id','vehicle_Avg_mileage']
for parameter in parameters:
    distribution_percentile(parameter)
# Out:
# The histogram of: price
# The distribution is skewed to the right
# ---------------------------------------
# Statistics on: price
# count     51525.000000
# mean      12132.464920
# std       10040.803015
# min           1.000000
# 25%        5000.000000
# 50%        9000.000000
# 75%       16839.000000
# max      375000.000000
# Name: price, dtype: float64
# ---------------------------------------
# min border: 1950.0
# max border: 30300.0
# Most frequent value: 0    1
# dtype: int64
# ---------------------------------------
# The outliers are considered to be values below 1950.0 and above 30300.0
# We have 5141 values that we can consider outliers
# The histogram of: vehicle_age
# The distribution is skewed to the right
# ---------------------------------------
# Statistics on: vehicle_age
# count    51525.000000
# mean         8.513906
# std          6.112976
# min          0.000000
# 25%          4.000000
# 50%          8.000000
# 75%         12.000000
# max        110.000000
# ...

# %% [markdown]
# <u>Histogram Summery</u>
#
# 1. Price - We see meidan of 9K thats considered a normal values since we have 5.1K outliers. most cars have a vlue of  1 which    fall under the outlier defination. The hist is skewed to the right.
# 2. vehicle_age - Meidan is 8 years and 7 years is the most frequent value, normal values considered between 7-8 years. we have
#    4.2K outliers. the hist skewed to the right therfore we can assume that we have a positive connection here.
# 3. cylinders - Normal value can be considered 6 wjich is also the median. we have 585 outlier. most cars have a value of 8
#    (most frequent value)
# 4. condition_id - Normal value can be considered 3 which is 'excellent' condition. the graph is skewed to the left.
#    We have 1.86K that is considred outliers
# 5. vehicle_Avg_mileage - Normal value can be considered 13,375 mileage this is the median, the most frequent value is 0 ( the
#    assumption is its new cars or 'not used' cars). The graph is  skewed to the right.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ⚠️</b>
#
#
# Good job! Don't forget to add titles and axis labels so that the reader could easily understand what's going on in this graph. It is also a good habit to leave some comments under each graph. We do our job for the client and he or she may not understand the graph at all. That's why we need titels, labels and comments :)
#
#
# You can use the following piece of code:
# </div>
#
# ```python
#
# plt.title('Title')
# plt.xlabel('X')
# plt.ylabel('Y')
#
# ```
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# - What can we say about these distributions? What values are considered to be normal here? What price or odometer value most cars have?
#
#
# - Plese, adjust the price and mileage histograms, as it is quite difficult to analyze the distribution. </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
#
# <font color='red'>
#
# * Added labels to each graph
#
# * Set bins size to 30 for each graph for readability
#
# * Added a Summery with Commentes on all the graphs
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3✔️</b>
#
#
# Very good here 😊👍
# </div>

# %% [markdown]
# ## Study and treat outliers

# %%
# Determine the lower limits for outliers
# Determine the upper limits for outliers
limits = []
for parameter in parameters:
    ninety_five = np.percentile(df[parameter], 95)
    five = np.percentile(df[parameter], 5)
    outlier = len(df[(df[parameter]<five)|(df[parameter]>ninety_five)])
    outlier_share = round((len(df[(df[parameter]<five)|(df[parameter]>ninety_five)])/len(df))*100,2)
    limits.append([parameter,ninety_five,five,outlier,outlier_share])
    

limits_df = pd.DataFrame(limits,columns=['parameter','max_limit','min_limit','outlier','outlier_%'])
limits_df
# Out:
#              parameter  max_limit  min_limit  outlier  outlier_%
# 0                price    30300.0     1950.0     5141       9.98
# 1          vehicle_age       19.0        1.0     4222       8.19
# 2            cylinders        8.0        4.0      713       1.38
# 3         condition_id        4.0        2.0     1865       3.62
# 4  vehicle_Avg_mileage    38083.8      167.0     5092       9.88

# %%
# Store data without outliers in a separate DataFrame

price_mask = (df['price'] > 1950.0)&(df['price'] < 30300.0)
vehicle_age_mask=(df['vehicle_age'] > 1.0)&(df['vehicle_age'] < 19.0)
cylinders_mask=(df['cylinders'] > 4.0)&(df['cylinders'] < 8.0)
condition_id_mask=(df['condition_id'] > 2.0)&(df['condition_id'] < 4.0)
vehicle_Avg_mileage_mask=(df['vehicle_Avg_mileage'] > 0.0)&(df['vehicle_Avg_mileage'] < 38083.8)

df_z = np.abs(stats.zscore(df[('condition_id' != 5) and ['price','vehicle_age', 'cylinders','vehicle_Avg_mileage']]))
df_z
threshold = 3
print(np.where(df_z > 3))


df_filtered = df[(np.abs(stats.zscore(df[('condition_id' != 5) and ['price','vehicle_age', 'cylinders','vehicle_Avg_mileage']])) < 3).all(axis=1)]
df_filtered


# I tried somthing here but with no success i wanted to make a filtered df with masks but couldnt so i did it with Z-Score
# Out:
#           price  vehicle_age  cylinders  vehicle_Avg_mileage
# 0      0.272139     0.247657   0.043833             0.404380
# 1      1.331334     0.247657   0.043833             0.183695
# 2      0.660558     0.411245   0.093089             0.230268
# 3      1.058936     1.224635   0.005423             1.101128
# 4      0.275632     1.065597   0.093089             1.847732
# ...         ...          ...        ...                  ...
# 51520  0.287178     0.574833   0.043833             0.178642
# 51521  0.939423     1.224635   0.093089             0.280806
# 51522  0.814929     0.079519   0.093089             0.070351
# 51523  0.465850     0.574833   0.093089             0.930957
# 51524  0.580882     0.738421   0.093089             1.073560
#
# [51525 rows x 4 columns]
# (array([   63,    95,   188, ..., 51325, 51397, 51475]), array([1, 3, 0, ..., 1, 3, 3]))
#        price  model_year           model  condition  cylinders fuel  odometer  \
# ...

# %%
df_filtered[['price', 'vehicle_age', 'odometer', 'cylinders', 'condition_id']].describe().loc[['min', 'max']]
# Out:
#        price  vehicle_age  odometer  cylinders  condition_id
# min      1.0          0.0       0.0        3.0           0.0
# max  42000.0         26.0  920000.0       12.0           5.0

# %% [markdown]
# Used a Z-Score to track outlier with threshold of 3 to filter the outliers
# ***

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ✔️</b>
#
# > Used a Z-Score to track outlier with threshold of 3 to filter the outliers
#
#
# Very impressive! :)
#
#
#
# We should always check ourselves:
#
# </div>

# %%
# Reviewer's code

filtered_vehicles = df[(np.abs(stats.zscore(df[['price', 'vehicle_age', 'cylinders',
                                                'condition_id','vehicle_Avg_mileage']])) < 3).all(axis=1)]

print(len(filtered_vehicles))

filtered_vehicles[['price', 'vehicle_age', 'odometer', 'cylinders', 'condition_id']].describe().loc[['min', 'max']]
# Out:
# 49287
#        price  vehicle_age  odometer  cylinders  condition_id
# min      1.0          0.0       0.0        3.0           1.0
# max  42000.0         26.0  920000.0       12.0           4.0

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# - There's a typo in the code. Please, check it out.
#
#
# - Minimum price is 1 dollar.
#
#
# - Is it good to remove new and salvage cars from the dataframe? It's absolutely normal for the car to be new, so we can ignore this column and do not try to look for the outliers there, what do you think about it?
#
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ⚠️</b>
#
#
# If we are using a Z-score, do we need these masks? </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
#
# <font color='red'>
#
# * Fixid the typo
#
# * Your right it makes sense, removed the column 'price' from filter
#
# * My first idea was to create the filtered data with masks just couldent figure out how, so i did the Z-score insted
#
# </font>
# </div>

# %%
df.query('condition=="new" and vehicle_age==0')
# Out:
#        price  model_year                model condition  cylinders    fuel  \
# 663    30000        2018    toyota highlander       new          6     gas
# 833    44505        2019        dodge charger       new          8     gas
# 901    23000        2018          honda civic       new          4     gas
# 3342   26000        2018   chevrolet colorado       new          6     gas
# 4062   37490        2018    gmc sierra 2500hd       new          8     gas
# ...      ...         ...                  ...       ...        ...     ...
# 44304  20000        2018          ford fusion       new          4     gas
# 48229  19950        2018             ram 1500       new          6     gas
# 50077  19000        2018          honda civic       new          4     gas
# 50113  66000        2018            ford f250       new          8  diesel
# 51324  18995        2018  dodge grand caravan       new          6     gas
#
# ...

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 ❌</b>
#
# I mean, the minimum price is one dollar, which seems to be abnormal. I suppose, we should remove cars under 100 dollars. Moreover, although we can remove salvage cars, should we remove *new* cars? Especially if they are really new, if their age is 0? In other words, I think it is absolutely ok for the car to be new :) Yes, there are 140 new cars and 74 of them are 0 years old, but the point is, it is a separate vehicle category that is also supposed to be investigated. What do you think?
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Reviewer's comment 4 ✔️</h2>
#
# You can also do it manually and drop cars under 1000 dollars.
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
#
# <font color='red'>
# I did somthing maybe different hopefully that what you meant, i added a filter in line 121 for Z-score for condition_id that it wont take out 5 ('new')
# that way i dont remove new cars.
#
# </font>
# </div>

# %%
# Reviewer's code

df_filtered[['price', 'vehicle_age', 'odometer', 'cylinders', 'condition_id']].describe().loc[['min', 'max']]
# Out:
#        price  vehicle_age  odometer  cylinders  condition_id
# min      1.0          0.0       0.0        3.0           0.0
# max  42000.0         26.0  920000.0       12.0           5.0

# %% [markdown]
# ## Study core parameters without outliers

# %%
def distribution_percentile(parameter):
    print('The histogram of: {}'.format(parameter))
    df_filtered[parameter].hist()
    plt.show()
    if df_filtered[parameter].mean()>df_filtered[parameter].median():
        print('The distribution is skewed to the right')
    else:
        print('The distribution is skewed to the left')
    print('---------------------------------------')
    print('Statistics on: {}'.format(parameter))
    print(df_filtered[parameter].describe())
    #data[parameter].describe()
    ninety_five = np.percentile(df_filtered[parameter], 95)
    five = np.percentile(df_filtered[parameter], 5)
    print('---------------------------------------')
    print('min border:',five)
    print('max border:',ninety_five)
    print('---------------------------------------')
    print('The outliers are considered to be values below',five, "and above",ninety_five)
    print('We have',len(df_filtered[(df_filtered[parameter]<five)|(df_filtered[parameter]>ninety_five)]),"values that we can consider outliers")

# %%
parameters = ['price','vehicle_age','cylinders','condition_id','vehicle_Avg_mileage']
for parameter in parameters:
    distribution_percentile(parameter)
# Out:
# The histogram of: price
# The distribution is skewed to the right
# ---------------------------------------
# Statistics on: price
# count    49506.000000
# mean     11552.642043
# std       8525.562737
# min          1.000000
# 25%       4995.000000
# 50%       8995.000000
# 75%      15997.750000
# max      42000.000000
# Name: price, dtype: float64
# ---------------------------------------
# min border: 1900.0
# max border: 28990.0
# ---------------------------------------
# The outliers are considered to be values below 1900.0 and above 28990.0
# We have 4825 values that we can consider outliers
# The histogram of: vehicle_age
# The distribution is skewed to the right
# ---------------------------------------
# Statistics on: vehicle_age
# count    49506.000000
# mean         8.380903
# std          5.191001
# min          0.000000
# 25%          4.000000
# 50%          8.000000
# 75%         12.000000
# max         26.000000
# Name: vehicle_age, dtype: float64
# ...

# %% [markdown]
# <u>Histogram comparison</u>
#
# 1. price - count or data reduced from 51,525 to 49,354(relevent for all) which is 5% reductaion in the data.
#    max border reduced from 30,300 to 28,958
#    min border reduced from 1,950 to 1,989
#    the distribution of the hist is better represented on the X axis with the outliers out of the data in the Y
#
# 2. vehicle_age - max border reduced from 19 to 18
#    min border remians the same at 1.0
#    the distribution of the hist is more spread out on the X axis with max value at 26 years compered to 110 in unfiltered data
#    due to the outliers removed
#
# 3. cylinders - main cahnge is max values 12 in previues histogram and the max value after outlier removal is 10.0
#
# 4. condition_id - main cahnge is max values 5 in previues histogram and the max value after outlier removal is 4
#
# 5. vehicle_Avg_mileage - both histograms have 0 as the min border
#    max border reduced from ~38,100 to ~34,400
#    max value reduced significantly from 373,200 to 56,348
#    tje graph seem to be better distributed on X axis

# %% [markdown]
# ## Ads lifetime

# %%
df_filtered.days_listed.hist(bins = 50, figsize=(15, 8))
plt.title('Days_listed')
plt.xlabel('Days_listed')
plt.ylabel('frequency');

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ⚠️</b>
#
#
# Add `plt.show()` or a semicolon at the end of the code to get rid of output strings. </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
#
# <font color='red'>
#
# Done
#
# </font>
# </div>

# %%
df_filtered.days_listed.describe()
print('-------------------------------')
# Out:
# count    49506.000000
# mean        39.547994
# std         28.225645
# min          0.000000
# 25%         19.000000
# 50%         33.000000
# 75%         53.000000
# max        271.000000
# Name: days_listed, dtype: float64
# -------------------------------

# %% [markdown]
# Typical lifetime of and ad is between  0 to 50 days ( only based on the graph )
#
# if we take a look at the stats we see that car is listed on Avg ~40 days
#
# The fastest ads was removed at 0 days mark and abnormally long time for ads to still be listed is 271 days.
#
# ***

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# As a result, when ads were removed quickly and when they were listed for an abnormally long time?
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 ✔️</b>
#
# Agree. To answer such questions you can use quartiles. Under 1st quartile can be fast and aboce 3rd can be long.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
#
# <font color='red'>
#
# Added the info
#
# </font>
# </div>

# %% [markdown]
# ## Average price per each type of vehicle

# %%
df_filtered.pivot_table(index=['type'], values = 'price').sort_values('price',ascending=False).plot( kind = 'bar', grid=True,figsize=(15,5))
plt.title('price by type')
plt.xlabel('type')
plt.ylabel('price');

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ⚠️</b>
#
#
# Don't forget about sorting :) </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 ✔️</b>
#
# Looks better 👍</div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
#
# <font color='red'>
#
# Thanks :) it lookes much better
#
# </font>
# </div>

# %%
df_filtered.groupby(['type'])['price'].mean().sort_values(ascending = False )
# Out:
# type
# bus            17445.913043
# truck          15705.917900
# pickup         15462.975412
# offroad        14283.761658
# coupe          13662.346411
# convertible    12681.158038
# other          10674.542373
# SUV            10661.335051
# van            10463.245981
# wagon           8879.745550
# mini-van        7957.725439
# sedan           6889.598187
# hatchback       6772.907463
# Name: price, dtype: float64

# %% [markdown]
# bus and truck are the types that is on average the most expensive
# ***

# %%
df_filtered.pivot_table(index=['type'], values = 'days_listed').sort_values('days_listed',ascending=False).plot( kind = 'bar', grid=True,figsize=(15,5))
plt.title('days_listed by type')
plt.xlabel('type')
plt.ylabel('days_listed');

# %%
df_filtered.groupby(['type'])['days_listed'].describe().sort_values(by ='count',ascending = False)
# Out:
#                count       mean        std  min   25%   50%   75%    max
# type
# SUV          12034.0  39.832724  28.307823  0.0  19.0  33.5  54.0  243.0
# sedan        11916.0  39.454263  28.242303  0.0  19.0  33.0  53.0  271.0
# truck        11693.0  39.408877  27.825132  0.0  19.0  33.0  54.0  263.0
# pickup        6670.0  39.222789  27.670899  0.0  19.0  33.0  53.0  225.0
# coupe         2090.0  39.162201  28.746261  0.0  19.0  33.0  51.0  256.0
# wagon         1517.0  40.557020  30.458635  1.0  18.0  34.0  53.0  240.0
# mini-van      1140.0  39.199123  28.245876  0.0  19.0  33.0  52.0  173.0
# hatchback     1005.0  40.597015  29.419683  0.0  19.0  35.0  56.0  267.0
# van            622.0  40.382637  30.132048  0.0  19.0  33.0  54.0  185.0
# convertible    367.0  38.386921  27.399147  0.0  19.0  33.0  51.0  190.0
# other          236.0  37.944915  25.956288  4.0  19.0  32.0  50.0  151.0
# offroad        193.0  41.150259  32.715045  1.0  18.0  32.0  57.0  233.0
# ...

# %% [markdown]
# SUV and sedan have the most number of ads
# ***

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ✔️</b>
#
# Seems to be true.
# </div>

# %% [markdown]
# ## Price factors

# %%
top_type = df_filtered.query('type == "SUV" | type == "sedan"')
SUV = df_filtered.query('type == "SUV"')
SUV.corr()
print('------------------------------------------------------')
sedan = df_filtered.query('type == "sedan"')
sedan.corr()
# Out:
#                         price  model_year  cylinders  odometer    is_4wd  \
# price                1.000000    0.579861   0.018940 -0.376760  0.110658
# model_year           0.579861    1.000000  -0.264907 -0.435958 -0.074496
# cylinders            0.018940   -0.264907   1.000000  0.166294  0.124638
# odometer            -0.376760   -0.435958   0.166294  1.000000  0.029771
# is_4wd               0.110658   -0.074496   0.124638  0.029771  1.000000
# days_listed         -0.018752   -0.014277   0.015505  0.014740 -0.005666
# day_of_week          0.003309   -0.005511  -0.011115  0.006207  0.014619
# day                 -0.001660   -0.016692   0.003627  0.004780  0.010420
# month               -0.011714   -0.018155   0.003770  0.007249 -0.000238
# year                 0.006477    0.015295  -0.004967  0.002316 -0.006672
# vehicle_age         -0.577609   -0.995736   0.263693  0.434928  0.073667
# vehicle_Avg_mileage  0.195002    0.414281  -0.073351  0.423164 -0.026416
# ...

# %%
scatter_SUV = SUV[['price','vehicle_Avg_mileage','vehicle_age']]
sns.pairplot(scatter_SUV, diag_kind="hist",height= 4);

# %% [markdown]
# <u>Scatter Matrix Comments:</u>
#
# The main output of the matrix is that for SUV we see a negative correlation of -0.56 for vehicle_age we can see it in the graph as well as age goes up price does down.

# %%
scatter_sedan = sedan[['price','vehicle_Avg_mileage','vehicle_age']]
sns.pairplot(scatter_sedan, diag_kind="hist",height= 4);

# %% [markdown]
# <u>Scatter Matrix Comments:</u>
#
# Same as the SUV the main output of the matrix is that for sedan is that there is strong negative correlation of -0.60 for vehicle_age we can see it in the graph as well as age goes up price does down.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# - There's no price on the graph.
#
#
# - It would be great if the matrix was larger :) Try to use `figsize`.
#
#
#
# - Plese, leave a comment under each graph. I see that there's a general conclusion, but we should leave a comment about any result we recevie, be it a graph or a number.
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ⚠️</b>
#
#
# You can show condition distribution on the boxplot. It is a categorical variable, so it is ok to use a boxplot.
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
#
# <font color='red'>
#
# Changed the code a bit and included price as well.
# Added comments of each matrix
#
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 ✔️</b>
#
# Cool! :) </div>

# %%
SUV.transmission.value_counts()
# Out:
# automatic    11406
# manual         475
# other          153
# Name: transmission, dtype: int64

# %%
plt.figure(figsize=(8,10))
ax=sns.boxplot(x="transmission", y="price", data=SUV);

# %%
sedan.transmission.value_counts()
# Out:
# automatic    11214
# manual         573
# other          129
# Name: transmission, dtype: int64

# %%
plt.figure(figsize=(8,10))
ax=sns.boxplot(x="transmission", y="price", data=sedan);

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# There are 3 transmission types, so we are supposed to represent 3 boxes on this graph. Same can be said about color and condition.
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 ✔️</b>
#
# Absolutely right, great! Now we can notice the difference: automatic is more expensive for sedans and manual is more expensive for SUV-s. And automatic are more common for both types.</div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
#
# <font color='red'>
#
# Made boxplots with 3 transmission types
#
# </font>
# </div>

# %%
SUV.paint_color.value_counts()
# Out:
# unkown    2172
# black     2125
# white     1892
# silver    1533
# grey      1145
# blue      1007
# red        890
# green      431
# brown      368
# custom     306
# orange      78
# yellow      48
# purple      39
# Name: paint_color, dtype: int64

# %%
plt.figure(figsize=(20,10))
ax=sns.boxplot(x="paint_color", y="price", data=SUV);

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 ✔️</b>
#
#
# Interesting. Maybe, these orange cars are rare and expensive. Sport cars or smth like this. </div>

# %%
sedan.paint_color.value_counts()
# Out:
# unkown    2149
# silver    2010
# black     1723
# grey      1597
# white     1476
# blue      1211
# red        934
# custom     292
# brown      258
# green      208
# purple      26
# yellow      23
# orange       9
# Name: paint_color, dtype: int64

# %%
plt.figure(figsize=(20,10))
ax=sns.boxplot(x="paint_color", y="price", data=sedan);

# %%
SUV.condition.value_counts()
# Out:
# excellent    6338
# good         4219
# like new     1119
# fair          320
# salvage        20
# new            18
# Name: condition, dtype: int64

# %%
plt.figure(figsize=(20,15))
ax=sns.boxplot(x="condition", y="price", data=SUV);

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 ✔️</b>
#
# *like new* has a higher median, which is really true. </div>

# %%
sedan.condition.value_counts()
# Out:
# excellent    6002
# good         4249
# like new     1292
# fair          289
# new            45
# salvage        39
# Name: condition, dtype: int64

# %%
plt.figure(figsize=(20,15))
ax=sns.boxplot(x="condition", y="price", data=sedan);

# %%
df.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400        2011          bmw x5       good          6  gas    145000
# 1  25500        2011       ford f150       good          6  gas     88705
# 2   5500        2013  hyundai sonata   like new          4  gas    110000
# 3   1500        2003       ford f150       fair          8  gas      2011
# 4  14900        2017    chrysler 200  excellent          4  gas     80903
#
#   transmission    type paint_color  is_4wd date_posted  days_listed  \
# 0    automatic     SUV      unkown     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     0.0  2019-02-07           79
# 3    automatic  pickup      unkown     0.0  2019-03-22            9
# 4    automatic   sedan       black     0.0  2019-04-02           28
#
#    day_of_week  day  month  year  vehicle_age  vehicle_Avg_mileage  \
# ...

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# To sum up, in this part of the project we have to compare two types of cars separately. Please, make sure, that there are graps for suv and sedan, for each of the parameters `age, mileage, condition, transmission type, and color. `.
#
#
# Use scatter plot to represent the connection between price and the first 2 parameters (there should be 2 graphs: price-age and price-mileage) and boxplot for the last 3 parameters. Each boxplot should include several boxes. For instance, a boxplot of a price distribution depending on transmission type should have 3 boxes: one for each type of transmission.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
#
# <font color='red'>
#
# Made Boxplots for condition, transmission type, and color with a few boxes
#
# The connection between price was handeled above already
# </font>
# </div>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment 3 ⚠️</b>
#
#
# That's good. Please, don't forget about conclusions in the next projects :) The main task of any analyst is to explain data. And for this purpose we use visualization. So, charts are not our goal, but our tool.
# </div>

# %% [markdown]
# ## General conclusion

# %% [markdown]
# **In the study we can conclude that a few parameters affect the price of a car:**
#
# 1. model_year - the newer the car the more it costs
# 2. vehicle_age = negative correlation the older the car the less it costs
# 3. condition_id - significance correlation the better the conndition of a car the more it costs
#
# <u>What was done in order to get to a Conclusion</u>
#
# Missing values:
# - Looking first at the data we saw missing_values for income_type and for 5 columns:
#     * model_year -> was fillied with median
#     * is_4wd -> 4 wheel drive boolen type, na was filled with 0 (no 4 wheel drive)
#     * cylinders -> was filled with median using transforme method using groupby 'model'
#     * odometer -> missing values are filled with 0, the reason is a car can be new with 0 mileage when the ad was published or       in an unused condition
#     * paint color - > was filled with 'unknown' stringe since there is no why to know
#
# Duplicats:
# - In the column of the model i used replace the remove any duplication
#
# Datatypes:
# - changed 4 columns data types in order to be able to analyze the values in this column:
#   * date_posted ->changed the date format
#   * odometer -> to integer
#   * model_year -> to integer
#   * cylinders -> to integer
#
# Outliers in the DataFrame:
#
# - I used Z-Score in order the detect outlier:
#   * created spreate DataFrame without the outliers -> 2,171 around ~5% of the orginal DataFrame
#   * used the filtered the data for further analysis

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment ✔️</b>
#
#
# The conclusion has a good structure 👍</div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Reviewer's comment  ❌</b>
#
# Please, do not forget to reconsider it.
# </div>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <h2> Overall conclusion</h2>
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# You've done a really good job!
#
# - You've shown good analytical and coding skills.
#
#
# - The data was prepared successfully.
#
#
# - There are a lot graphs. It is good, visualization never hurts.
#
#
# - Moreover, the project has a great conclusion, which is also important.
#
# </div>
#
#
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# There are some issues that need to be fixed, but it will not take much time.
#
#
# As soon as you fix them I will accept the project 😉
#
# </div></div>
